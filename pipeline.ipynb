# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

import query_gaia
import forward_model
import ruwe_calculation
import inference
import mass_estimate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 8
#       6 import forward_model
#       7 import part3
# ----> 8 import mass_estimate
#
# File ~/Desktop/projects/tgaia/mass_estimate.py:6
#       4 import pytensor.tensor as at
#       5 import matplotlib.pyplot as plt
# ----> 6 from jax import random
#       7 from jaxstar import mistfit
#       8 from astroquery.gaia import Gaia
#
# ModuleNotFoundError: No module named 'jax'

# %%
# Target: HD 141937 with Gaia DR3 6248534171318085376
from part1 import gaia_query
gaia_query('6248534171318085376')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Target: HD 141937 with Gaia DR3 6248534171318085376
#       2 from part1 import gaia_query
# ----> 3 gaia_query('6248534171318085376')
#
# File ~/Desktop/projects/tgaia/part1.py:23, in gaia_query(source_id)
#      21 def gaia_query(source_id):
#      22     name = 'Gaia DR3 ' + source_id
# ---> 23     result_table = Gaia.query_object_async(name)
#      24     all_ids = result_table['designation'].tolist()
#      25     print(all_ids)
#
# File ~/miniforge3/envs/tgaia/lib/python3.13/site-packages/astroquery/gaia/core.py:604, in GaiaClass.query_object_async(self, coordinate, radius, width, height, verbose, columns)
#     580 def query_object_async(self, coordinate, *, radius=None, width=None, height=None, verbose=False, columns=()):
# ...

# %%
planet_models = forward_model.load_planet_models()

# %%
t_obs = find_obs(0)
scan_angle = find_obs(1)
parallax_factor = find_obs(2)
ra_diffs = radec_diff(0)
dec_diffs = radec_diff(1)
